# %% [markdown]
# <a href="https://colab.research.google.com/github/dan00721/python_practice/blob/main/%D0%94%D0%BE%D0%BC%D0%B0%D1%88%D0%BD%D0%B5%D0%B5_%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_%C2%AB%D0%91%D0%B8%D0%B1%D0%BB%D0%B8%D0%BE%D1%82%D0%B5%D0%BA%D0%B0_Pandas%C2%BB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Задание 1
# Скачайте с сайта https://grouplens.org/datasets/movielens/ датасет любого размера. Определите какому фильму было выставлено больше всего оценок 5.0.

# %%
import pandas as pd

# %%
ratings = pd.read_csv('ml-latest-small/ratings.csv')
ratings.head()
# Out:
#    userId  movieId  rating    timestamp
# 0       1        1     4.0  964982703.0
# 1       1        3     4.0  964981247.0
# 2       1        6     4.0  964982224.0
# 3       1       47     5.0  964983815.0
# 4       1       50     5.0  964982931.0

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43084 entries, 0 to 43083
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   userId     43084 non-null  int64
#  1   movieId    43084 non-null  int64
#  2   rating     43084 non-null  float64
#  3   timestamp  43083 non-null  float64
# dtypes: float64(2), int64(2)
# memory usage: 1.3 MB

# %%
ratings[ratings['rating'] == 5]['movieId'].value_counts().head(10) # фильму с id = 318
# Out:
# 318     64
# 356     53
# 2571    51
# 296     51
# 260     48
# 593     43
# 527     37
# 1210    37
# 1196    36
# 2959    35
# Name: movieId, dtype: int64

# %%
movies = pd.read_csv('ml-latest-small/movies.csv')
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movies[ movies['movieId'] == 318] # расшифровка фильма
# Out:
#      movieId                             title       genres
# 277      318  Shawshank Redemption, The (1994)  Crime|Drama

# %% [markdown]
# ### Задание 2
# По данным файла power.csv посчитайте суммарное потребление стран Прибалтики (Латвия, Литва и Эстония) категорий 4, 12 и 21 за период с 2005 по 2010 года. Не учитывайте в расчетах отрицательные значения quantity.

# %%
power = pd.read_csv('power.csv')
power.head()
# Out:
#    country  year  quantity  category
# 0  Austria  1996       5.0         1
# 1  Austria  1995      17.0         1
# 2  Belgium  2014       0.0         1
# 3  Belgium  2013       0.0         1
# 4  Belgium  2012      35.0         1

# %%
power_filtered = power[ (power['country'].isin(['Latvia', 'Estonia', 'Lithuania']))
                        &(power['category'].isin([4, 12, 21]))
                        & ((power['year'] >= 2005) & (power['year'] <= 2010)) ]
power_filtered
# Out:
#           country  year  quantity  category
# 10617     Estonia  2008       1.0         4
# 10618     Estonia  2007       0.0         4
# 10619     Estonia  2006       0.0         4
# 10620     Estonia  2005       1.0         4
# 11156   Lithuania  2008       1.0         4
# ...           ...   ...       ...       ...
# 253982  Lithuania  2009      98.0        21
# 253983  Lithuania  2008      54.0        21
# 253984  Lithuania  2007      47.0        21
# 253985  Lithuania  2006      31.0        21
# 253986  Lithuania  2005       1.0        21
#
# [411 rows x 4 columns]

# %%
power_filtered[ power_filtered['quantity'] > 0 ]['quantity'].sum() # суммарное потребление
# Out:
# 240580.0

# %% [markdown]
# ### Задание 3
# Выберите страницу любого сайта с табличными данными. Импортируйте таблицы в pandas dataframe.
# Примеры страниц (необязательно брать именно эти):
# * https://fortrader.org/quotes
# * https://www.finanz.ru/valyuty/v-realnom-vremeni

# %%
pd.read_html('https://www.finanz.ru/valyuty/v-realnom-vremeni', attrs={'class': 'quote_list'}, encoding='utf-8')
# Out:
# [    Unnamed: 0              Рубль  Предложение  Спрос  Предыдущее закрытие  \
#  0          NaN            GBP/RUB      1529235      -              1746981
#  1          NaN            EUR/RUB      1403895      -              1438985
#  2          NaN            USD/RUB      1343750      -              1335000
#  3          NaN            JPY/RUB        09995      -                11495
#  4          NaN            CNY/RUB       184667      -               211171
#  5          NaN            CHF/RUB      1254824      -              1435638
#  6          NaN               Евро  Предложение  Спрос  Предыдущее закрытие
#  7          NaN            EUR/USD        10936      -                10987
#  8          NaN            EUR/GBP        08372      -                08397
#  9          NaN            EUR/JPY      1280890      -              1276100
#  10         NaN            EUR/CHF        10201      -                10218
# ...

# %%
pd.read_html('https://smart-lab.ru/q/shares/', attrs={'class': 'simple-little-table'}, encoding='utf-8')
# Out:
# [       № Unnamed: 1     Название  Тикер Unnamed: 4 Unnamed: 5 Unnamed: 6  \
#  0    NaN   18:51:01  Индекс ММВБ  IMOEX        NaN        NaN        NaN
#  1      1   15:10:04     Сбербанк   SBER        NaN        NaN        NaN
#  2      2   15:10:04   ГАЗПРОМ ао   GAZP        NaN        NaN        NaN
#  3      3   15:10:04   Yandex clA   YNDX        NaN        NaN        NaN
#  4      4   15:10:04     Роснефть   ROSN        NaN        NaN        NaN
#  ..   ...        ...          ...    ...        ...        ...        ...
#  278  276   15:10:04   ГазпРнД ао   RTGZ        NaN        NaN        NaN
#  279  277   15:10:04   Русполимет   RUSP        NaN        NaN        NaN
#  280  278   15:10:04    ТрансК ао   TRCN        NaN        NaN        NaN
#  281  279   15:10:04    ТрансФ ао   TRFM        NaN        NaN        NaN
#  282  280   15:10:04   Уркалий-ао   URKA        NaN        NaN        NaN
#
#      Цена, посл   Изм, % Объем, млн руб 1 нед, %  1 м, %  ytd, %  12м, %  \
# ...
